# %% [markdown]
# <a id='top'></a>
# # World Food Programme: food price and affordability analysis
# ### Data scraping
#
# This script illustrates the first phase of the 'World Food Programme: Food Price and Affordability Analysis' project. The project is using data from the World Food Programme Price Database.
#
# The World Food Programme is monitoring the price of staple foods included in a [basic food basket](https://humanitarianglobal.com/key-tools-and-types-of-information-required-for-monitoring-the-adequacy-of-ration-in-emergencies/#:~:text=Food%20Basket%20Monitoring%20(FBM)&text=A%20systematic%20sample%20of%20households,each%20of%20their%20food%20items) across 99 countries. In the World Food Programme Price Database, the data is stored and can be downloaded at a country level.
#
# I aim to merge the available data to gain a global perspective on food price dynamics. The following Python code was used to create a combined food price data set in 3 steps:
#
# 1. [Scraping](#scrape)
#
# With the list of URLs from ['wfp_countries_global.csv'](https://www.kaggle.com/datasets/jocelyndumlao/global-food-prices?select=wfp_countries_global.csv) I can gain access to each page on [OCHA Services](https://data.humdata.org/dataset?dataseries_name=WFP+-+Food+Prices) where the food price data for each country can be downloaded in a.csv format. Using BeautifulSoup, I've scraped each of the pages to retrieve the links to the individual country data.
#
# 2. [Using a for loop to download 99 individual data sets](#download)
#
# Using the list of links to the individual data sets, I've created a for loop to download all the files.
#
# 3. [Combining the data into a single data set](#concat)
#
# Using pd.concat, I combined the data from the 99 individual data sets into one single dataframe and exported it for further analysis.

# %%
import pandas as pd
import numpy as np
import os
from time import sleep
from bs4 import BeautifulSoup
import requests
from os.path import basename
import urllib.request

# %% [markdown]
# <a id='scrape'></a>
# ## Scraping
# [Back to top](#top)

# %%
path=r'C:\Users\frauz\Documents\Python Projects\Final Project\Data' #creating a path the store the files

df_countries=pd.read_csv(os.path.join(path,'wfp_countries_global.csv'), index_col=False) #import the dataset with all the countries and links

# %%
df_countries.head()
# Out:
#      countryiso3                                                url  \
# 0  #country+code                                       #country+url
# 1            AFG  https://data.humdata.org/dataset/wfp-food-pric...
# 2            AGO  https://data.humdata.org/dataset/wfp-food-pric...
# 3            ARG  https://data.humdata.org/dataset/wfp-food-pric...
# 4            ARM  https://data.humdata.org/dataset/wfp-food-pric...
#
#                   start_date                   end_date
# 0                #date+start                  #date+end
# 1  2000-01-15 00:00:00+00:00  2024-02-15 23:59:59+00:00
# 2  2008-01-15 00:00:00+00:00  2021-05-15 23:59:59+00:00
# 3  2005-01-15 00:00:00+00:00  2022-12-15 23:59:59+00:00
# 4  1996-01-15 00:00:00+00:00  2024-01-15 23:59:59+00:00

# %%
df_countries=df_countries.drop([0]) # dropping the unnecesarry row

df_countries.head()

# %%
url_list=df_countries['url'].to_list() # creating a list of links
len(url_list)
# Out:
# 99

# %%
country_list=df_countries['countryiso3'].to_list() # creating a list of countries
country_list
# Out:
# ['AFG',
#  'AGO',
#  'ARG',
#  'ARM',
#  'AZE',
#  'BDI',
#  'BEN',
#  'BFA',
#  'BGD',
#  'BLR',
#  'BOL',
#  'BTN',
#  'CAF',
#  'CHN',
#  'CIV',
#  'CMR',
#  'COD',
#  'COG',
#  'COL',
#  'CPV',
#  'CRI',
#  'DJI',
#  'DOM',
#  'DZA',
#  'ECU',
#  'EGY',
#  'ERI',
#  'ETH',
#  'FJI',
#  'GAB',
#  'GEO',
#  'GHA',
#  'GIN',
#  'GMB',
#  'GNB',
#  'GTM',
#  'HND',
#  'HTI',
#  'IDN',
#  'IND',
#  'IRN',
#  'IRQ',
#  'JOR',
#  'JPN',
#  'KAZ',
#  'KEN',
#  'KGZ',
#  'KHM',
#  'LAO',
#  'LBN',
#  'LBR',
#  'LBY',
#  'LKA',
#  'LSO',
#  'MDA',
#  'MDG',
#  'MEX',
#  'MLI',
#  'MMR',
#  'MNG',
#  'MOZ',
#  'MRT',
#  'MWI',
#  'NAM',
#  'NER',
#  'NGA',
#  'NIC',
#  'NPL',
#  'PAK',
#  'PAN',
#  'PER',
#  'PHL',
#  'PRY',
#  'PSE',
#  'RUS',
#  'RWA',
#  'SDN',
#  'SEN',
#  'SLE',
#  'SLV',
#  'SOM',
#  'SSD',
#  'SWZ',
#  'SYR',
#  'TCD',
#  'TGO',
#  'THA',
#  'TJK',
#  'TLS',
#  'TUR',
#  'TZA',
#  'UGA',
#  'UKR',
#  'VEN',
#  'VNM',
#  'YEM',
#  'ZAF',
#  'ZMB',
#  'ZWE']

# %%
url_list[1] # extract 1 link we are going to use for testing the code
# Out:
# 'https://data.humdata.org/dataset/wfp-food-prices-for-angola'

# %%
page=requests.get('https://data.humdata.org/dataset/wfp-food-prices-for-angola').text # open the link
print(page) # get everything from the page
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]> <html lang="en_AU" class="ie ie7"> <![endif]-->
# <!--[if IE 8]> <html lang="en_AU" class="ie ie8"> <![endif]-->
# <!--[if IE 9]> <html lang="en_AU" class="ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en_AU"> <!--<![endif]-->
#   <head>
#
#     <script type="application/javascript">
#       /**
#        * A map holding all the information to be sent to the analytics servers
#        * @type {object}
#        */
#       var analyticsInfo = {
#           'organizationName': 'wfp',
#           'organizationId': '3ecac442-7fed-448d-8f78-b385ef6f84e7',
#           'groupNames': ["ago"],
#           'groupIds': ["ago"],
#           'isCod': false,
#           'isIndicator': false,
#           'isArchived': false,
#           'datasetName': 'wfp-food-prices-for-angola',
#           'datasetId': 'f6155f17-bded-468c-b926-b9de5034d2ad',
#           'pageTitle': 'Angola - Food Prices',
#           'datasetAvailability': 'public',
#           'authenticated': 'false'
#
#       };
#     </script>
#
#
#         <!-- start Mixpanel -->
# <script type="text/javascript">
#     (function (e, b) {
#         if (!b.__SV) {
#             var a, f, i, g;
#             window.mixpanel = b;
#             b._i = [];
#             b.init = function (a, e, d) {
#                 function f(b, h) {
#                     var a = h.split(".");
#                     2 == a.length && (b = b[a[0]], h = a[1]);
#                     b[h] = function () {
#                         b.push([h].concat(Array.prototype.slice.call(arguments, 0)))
#                     }
#                 }
#
#                 var c = b;
#                 "undefined" !== typeof d ? c = b[d] = [] : d = "mixpanel";
#                 c.people = c.people || [];
#                 c.toString = function (b) {
#                     var a = "mixpanel";
#                     "mixpanel" !== d && (a += "." + d);
#                     b || (a += " (stub)");
#                     return a
#                 };
#                 c.people.toString = function () {
#                     return c.toString(1) + ".people (stub)"
#                 };
#                 i = "disable time_event track track_pageview track_links track_forms register register_once alias unregister identify name_tag set_config reset people.set people.set_once people.increment people.append people.union people.track_charge people.clear_charges people.delete_user".split(" ");
#                 for (g = 0; g < i.length; g++)f(c, i[g]);
#                 b._i.push([a, e, d])
#             };
#             b.__SV = 1.2;
#             a = e.createElement("script");
#             a.type = "text/javascript";
#             a.async = !0;
#             a.src = "undefined" !== typeof MIXPANEL_CUSTOM_LIB_URL ? MIXPANEL_CUSTOM_LIB_URL : "file:" === e.location.protocol && "//cdn.mxpnl.com/libs/mixpanel-2-latest.min.js".match(/^\/\//) ? "https://cdn.mxpnl.com/libs/mixpanel-2-latest.min.js" : "//cdn.mxpnl.com/libs/mixpanel-2-latest.min.js";
#             f = e.getElementsByTagName("script")[0];
#             f.parentNode.insertBefore(a, f)
#         }
#     })(document, window.mixpanel || []);
#     mixpanel.init("5cbf12bc9984628fb2c55a49daf32e74");
#
#     var mixpanelTrackData = {
#       "page title": analyticsInfo.pageTitle,
#       "org name": analyticsInfo.organizationName,
#       "org id": analyticsInfo.organizationId,
#       "group names": analyticsInfo.groupNames,
#       "group ids": analyticsInfo.groupIds,
#       "authenticated": analyticsInfo.authenticated,
#       "dataset availability": analyticsInfo.datasetAvailability,
#       "is cod": analyticsInfo.isCod,
#       "is indicator": analyticsInfo.isIndicator,
#       "is archived": analyticsInfo.isArchived,
#       "dataset id": analyticsInfo.datasetId,
#       "dataset name": analyticsInfo.datasetName
#     };
#
#     mixpanel.track("page view", mixpanelTrackData);
# </script>
# <!-- end Mixpanel -->
#
#
#
#       <!-- Google Tag Manager - DATALAYER -->
#       <script type="application/javascript">
#         window.dataLayer = window.dataLayer || [];
#
#         <!-- Google Analytics - custom properties (dimensions) -->
#         (function() {
#             if (analyticsInfo.organizationName !== 'None') {
#                 dataLayer.push({
#                   'org_name': analyticsInfo.organizationName
#                 });
#             }
#
#
#
#             var locationNames = analyticsInfo.groupNames.length < 15 ? analyticsInfo.groupNames.join('~') : 'many';
#             if (locationNames) {
#                 dataLayer.push({
#                   'location_names': locationNames
#                 });
#             }
#         }());
#         <!-- END - Google Analytics - custom properties (dimensions) -->
#       </script>
#       <!-- Google Tag Manager -->
#       <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-MFNPQ7K');</script>
#       <!-- End Google Tag Manager -->
#
#
#
#
#
#     <meta charset="utf-8" />
#       <meta name="referrer" content="always">
#       <meta name="generator" content="ckan " />
#     <title>Angola - Food Prices  - Humanitarian Data Exchange</title>
#
#
#
#     <meta property="og:image" content="https://data.humdata.org/images/hxl_fb-01.png">
#     <meta property="og:image:type" content="image/jpeg">
#     <meta property="og:image:width" content="1200">
#     <meta property="og:image:height" content="630">
#
#
#
#   <link rel="alternate" media="only screen and (max-width: 640px)" href="/m/dataset/wfp-food-prices-for-angola?">
#   <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">
#       <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">
#       <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">
#       <link rel="manifest" href="/site.webmanifest">
#
#       <meta name="msapplication-TileColor" content="#da532c">
#       <meta name="theme-color" content="#ffffff">
#       <link rel="search" type="application/opensearchdescription+xml" title="HDX Search" href="/xml/opensearch.xml">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <link rel="alternate" type="application/ld+json" href="https://data.humdata.org/dataset/f6155f17-bded-468c-b926-b9de5034d2ad.jsonld?profiles=schemaorg"/>
#   <link rel="alternate" type="text/n3" href="https://data.humdata.org/dataset/f6155f17-bded-468c-b926-b9de5034d2ad.n3"/>
#   <link rel="alternate" type="text/ttl" href="https://data.humdata.org/dataset/f6155f17-bded-468c-b926-b9de5034d2ad.ttl"/>
#   <link rel="alternate" type="application/rdf+xml" href="https://data.humdata.org/dataset/f6155f17-bded-468c-b926-b9de5034d2ad.xml"/>
#
#
#
#
#
#
# <style>
#
#     body .container .org-custom-styling h1, body .container .org-custom-styling a:after, body .container .org-custom-styling a {
#       color: #2a93fc !important;
#     }
#
#
#
#     body .container .org-logo-large {
#       background-color: #2a93fc;
#     }
#
# </style>
#
#
#
#
#
#
#
#
#     <link href="/webassets/vendor/f3b8236b_select2.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/32e8c032_banner-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/eb37686d_page-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/e6060e4f_popup-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/575972bc_onboarding-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/36defdb8_onboarding-verify-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/a0f39bf8_onboarding-survey-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/8eacbf84_requestdata-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/a8fb351e_dataset-search-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/3efbe820_charting-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/ab3c0de2_dataset-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/83d358c6_contact-contributor-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/70aa3885_group-message-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-requestdata/5e97db77_main-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/a4942267_resource-list-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/e073633b_activity-stream-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/1ae6219c_dataset-quick-edit-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/514c6d99_base-org-styles.css" rel="stylesheet"/>
#
#   </head>
#
#
#   <body data-site-root="/" data-locale-root="/" data-api-root="">
#     <!-- Google Tag Manager (noscript) -->
#     <noscript>
#       <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MFNPQ7K" height="0" width="0" style="display:none;visibility:hidden"></iframe>
#     </noscript>
#     <!-- End Google Tag Manager (noscript) -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div id="logoutPopup" class="popup popup-onbording" style="display: none;" >
#     <div class="content  container-fluid">
#
#             <div class="row">
#
#                 <div class="col-xs-12">
#
#     <div class="notification-widget">
#         <div class="notification-title">
#
#                 You logged out of HDX
#
#             <i class="close humanitarianicons-Exit-Cancel"></i>
#         </div>
#         <div>
#             <div>
#
#     <div class="logout-widget">
#         <div class="center">
#             <img class="mTop20 lazyload" data-src="/images/onboarding/logout.png">
#             <div class="mTop30 notification-message">
#                 Thank you for using HDX !
#             </div>
#         </div>
#     </div>
#
#             </div>
#         </div>
#     </div>
#
#                 </div>
#
#             </div>
#
#     </div>
# </div>
#
#
#
#
#
#
#
# <div id="loginPopup" class="popup popup-onboarding" style="display: none;" >
#     <div class="content  container-fluid">
#
#             <div class="row">
#
#                 <div class="col-xs-12">
#
#     <div class="login-widget">
#         <div class="row">
#             <div class="login-top">
#                 <div class="login-photo center">
#                     <div id="login-photo-gravatar" style="display: none;">
#                         <img id="login-photo-gravatar-img" src="" class="gravatar" width="95" height="95">
#                     </div>
#                     <i id="login-photo-default" class="glyphicon glyphicon-user" style="
#                         color: white;
#                         font-size: 60px;
#                         text-align: center;
#                         top: 16px;
#                     "></i>
#                 </div>
#                 <i class="close humanitarianicons-Exit-Cancel"></i>
#             </div>
#         </div>
#         <div class="row">
#             <form id="hdx-login-form" action="/login_generic?came_from=/dataset/wfp-food-prices-for-angola" method="post" onsubmit="checkLockout">
#                 <div class="login-content">
#                     <div class="col-xs-12">
#                         <div id="login-info-message" class="error-explanation alert alert-danger mBottom5 pTopBottom5" style="display: none;">
#
#                         </div>
#                         <div id="username-static" class="username-static" style="display: none;">
#                             <div id="user-display-name" class="username-text center"></div>
#                             <div class="email-text center"> <span id="user-display-email"></span>&nbsp;<span><a onclick="notYou()" href="#">Not you?</a></span></div>
#                         </div>
#                         <div id="username-form-field" class="username mTop10 control">
#                             <input id="field-login" name="login" class="full-width required" type="text" value="" required>
#                             <label for="field-login">Email</label>
#                         </div>
#                         <div class="password mTop10 control">
#                             <input id="field-password" name="password" class="full-width required" type="password" required>
#                             <label for="field-password">Password</label>
#                         </div>
#                         <div id="mfa-form-field" style="display: none;" class="mfa mTop10 control">
#                             <input id="field-mfa" name="mfa" class="full-width required" type="number" min="0" max="999999" required>
#                             <label for="field-mfa">One Time Password</label>
#                         </div>
#                         <div class="error-message" style="display: none;">
#
#                         </div>
#                         <div class="checkbox-style mTop10"><input id="field-remember" name="remember" type="checkbox" value="63072000"><label for="field-remember">Remember me</label> </div>
#                         <div class="mTop10"><input class="full-width btn btn-primary btn-large" type="submit" value="Login" disabled></div>
#                         <div class="member center mTop10"><a href="/user/reset">Forgot your password?</a></div>
#                         <div class="member center">Not a member? <a href="#" onclick="closeCurrentWidget(this);spawnRecaptcha('#signupPopup');showOnboardingWidget('#signupPopup');" aria-label="register">Register</a></div>
#                     </div>
#                 </div>
#             </form>
#         </div>
#         <div>
#
#         </div>
#     </div>
#
#                 </div>
#
#             </div>
#
#     </div>
# </div>
#
#
#
#
# <div id="signupPopup" class="popup popup-onboarding" style="display: none;" >
#     <div class="content  container-fluid">
#
#             <div class="row">
#
#                 <div class="col-xs-12">
#
#     <div class="signup-widget">
#         <i class="close humanitarianicons-Exit-Cancel" ></i>
#         <div class="inner-bg">
#             <div class="row">
#                 <div class="col-sm-6 col-xs-12">
#
#                     <div class="large-title">
#                         Sign up with HDX <strong>to join the community</strong> and <strong>access more features</strong>
#                     </div>
#                     <br/>
#                     <span class="bold-regular-text">
#                         By signing up you can:
#                     </span>
#                     <ul class="signup-list">
#                         <li>Follow the latest changes to data, locations, organisations, topics and crises</li>
#                         <li class="starred">Share data publicly or privately</li>
#                         <li class="starred">Add data visualizations as gallery items alongside datasets</li>
#                         <li>Contact data contributors</li>
#                         <li class="starred-reason">You need to be affiliated with an organization to access these features</li>
#                     </ul>
#                     <!--<a class="btn btn-demo signup-action" type="button" href="https://www.youtube.com/watch?v=P8XDNmcQI0o" target="_blank"> See HDX in action <i class="glyphicon glyphicon-play"></i></a>-->
#                 </div>
#                 <div class="col-sm-6 col-xs-12">
#                     <form id="signup-form" onsubmit="return false;">
#                         <div class="signup-box">
#                             <div class="control">
#                                 <input id="field-email" name="email" class="full-width required" required="required" type="text" autocomplete="off">
#                                 <label for="field-email">Your Email Address</label>
#                             </div>
#                             <div class="error-message" style="display: none;line-height: 15px;"></div>
#                             <div class="mTop10 mBottom10">
#                                 <div class="checkbox-row">
#                                     <input id="signup-send-updates" name="signup-send-updates" type="checkbox" checked="checked"><label for="signup-send-updates">I'd like to sign up for the Centre for Humanitarian Data Newsletter</label>
#                                 </div>
#                                 <div class="checkbox-row" data-module="hdx_terms_checkbox" data-module-button="recaptcha">
#                                     <input id="signup-terms" name="signup-terms" type="checkbox" required="required" checked="checked"><label for="signup-terms">I have read and accept the <a target="_blank" href="/faqs/terms">HDX Terms of Service</a></label>
#                                 </div>
#                             </div>
#                             <input id="recaptcha" class="mTop10 full-width btn btn-primary btn-large hdx-recaptcha"
#                                    type="submit" value="Sign up" data-sitekey="6Lcl60EUAAAAAE46a3XcPM2nPUKI2K4XZbcsorkR" disabled
#                                    data-callback="signupFormOnSubmit" data-size="invisible" data-badge="inline"
#                                    >
#                             <div class="member center mTop10">Already a member? <a href="#" onclick="closeCurrentWidget(this);showOnboardingWidget('#loginPopup');" aria-label="sign in">Sign in</a></div>
#                         </div>
#                     </form>
#                 </div>
#             </div>
#         </div>
#
#     </div>
#
#                 </div>
#
#             </div>
#
#     </div>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div id="verifyPopup" class="popup popup-onboarding" style="display: none;" >
#     <div class="content  container-fluid">
#
#             <div class="row">
#
#                 <div class="col-xs-12">
#
#     <div class="notification-widget">
#         <div class="notification-title">
#
#                 We&#39;ve received your request !
#
#             <i class="close humanitarianicons-Exit-Cancel"></i>
#         </div>
#         <div>
#             <div>
#
#     <div class="verify-widget">
#         <div class="center">
#             <img class="gif mTop45 lazyload" data-src="/images/onboarding/incomingmail.gif">
#             <div class="notification-message mTop20">Click on the verification email we sent to:</div>
#             <div class="verify-email mTop10">-</div>
#         </div>
#     </div>
#
#             </div>
#         </div>
#     </div>
#
#                 </div>
#
#             </div>
#
#     </div>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div id="surveyPopup" class="popup popup-onbording" style="display: none;" >
#     <div class="content  container-fluid">
#
#             <div class="row">
#
#                 <div class="col-xs-12">
#
#     <div class="notification-widget">
#         <div class="notification-title">
#
#                 Data Literacy Survey
#
#             <i class="close humanitarianicons-Exit-Cancel"></i>
#         </div>
#         <div>
#             <div>
#
#   <div class="survey-widget">
#     <div class="center">
#       <div style="text-align: justify;">
#         Want to improve your data skills? Take this 5 minute survey to help the Centre shape its data literacy resources for humanitarians.
#       </div>
#
#     </div>
#     <div class="right-side-actions">
#       <input class="btn btn-empty btn-empty-black btn-large pull-left" type="button" onclick="closeCurrentWidget(this);" value="Close">
#       <a href="#"  class="mL35 btn btn-primary btn-large pull-right" type="button" value="Take survey">Take the survey</a>
#     </div>
#   </div>
#
#             </div>
#         </div>
#     </div>
#
#                 </div>
#
#             </div>
#
#     </div>
# </div>
#
#
#
#
#       <div class="container">
#         <div class="paddingRowHack">
#
#
#
#
#
#
#
#
#
#
#
# <!-- MOBILE NAV START -->
# <nav class="navbar navbar-static-top new-header" role="navigation">
#     <div class="global-header"> <!-- header is streched for the homepage -->
#     <div class="header-message global-header-bg">
#         <div class="header-message-container">
#             <img class="header-message-image lazyload" data-src="/images/empty.png" />
#         </div>
#     </div>
#     <div class="global-header-bg">
#       <div class="container">
#         <div class="row">
#           <div class="col-xs-12 global-header-content">
#             <a href="#" data-toggle="dropdown" class="ocha-services" aria-label="OCHA services">
#               <span class="ocha-logo"></span>
#               <span class="ocha-services-text">OCHA Services</span>
#
#               <svg class="icon-o-arrow-up" viewBox="0 0 48 48"><path d="M0,34a4,4,0,0,1,1.17-2.83l20-20a4,4,0,0,1,5.66,0l20,20a4,4,0,1,1-5.66,5.66L24,19.66,6.83,36.83A4,4,0,0,1,0,34Z"/></svg>
#               <svg class="icon-o-arrow-down" viewBox="0 0 48 48"><path d="M48,14a4,4,0,0,1-1.17,2.83l-20,20a4,4,0,0,1-5.66,0l-20-20a4,4,0,0,1,5.66-5.66L24,28.34,41.17,11.17A4,4,0,0,1,48,14Z"/></svg>
#             </a>
#             <div class="dropdown-menu ocha-services-menu" role="menu">
#               <div class="container">
#                 <div class="row">
#                   <div class="col-md-3 col-xs-12 section-spacing">
#                     <p class="list-title">
#                       Related Platforms
#                     </p>
#                     <ul class="ocha-links-list">
#                       <li>
#                         <a href="https://centre.humdata.org/" target="_blank" data-module="hdx_click_stopper" data-module-link_type="header">Centre for Humanitarian Data</a>
#                       </li>
#                       <li>
#                         <a href="https://hxlstandard.org/" target="_blank" data-module="hdx_click_stopper" data-module-link_type="header">Humanitarian Exchange Language (HXL)</a>
#                       </li>
#                     </ul>
#                   </div>
#                   <div class="col-md-3 col-xs-12">
#                     <p class="list-title">
#                       Other OCHA Services
#                     </p>
#                     <ul class="ocha-links-list">
#                       <li>
#                         <a href="https://fts.unocha.org/" target="_blank" data-module="hdx_click_stopper" data-module-link_type="header">Financial Tracking Service</a>
#                       </li>
#                       <li>
#                         <a href="https://data.humdata.org/" target="_blank" data-module="hdx_click_stopper" data-module-link_type="header">Humanitarian Data Exchange</a>
#                       </li>
#                       <li>
#                         <a href="https://humanitarian.id/" target="_blank" data-module="hdx_click_stopper" data-module-link_type="header">Humanitarian ID</a>
#                       </li>
#                       <li>
#                         <a href="https://hum-insight.info/" target="_blank" data-module="hdx_click_stopper" data-module-link_type="header">Humanitarian InSight</a>
#                       </li>
#                       <li>
#                         <a href="https://www.humanitarianresponse.info" target="_blank" data-module="hdx_click_stopper" data-module-link_type="header">Humanitarian Response</a>
#                       </li>
#                     </ul>
#                   </div>
#                   <div class="col-md-3 col-xs-12 section-spacing">
#                     <p class="list-title list-title-empty">
#                       &nbsp;
#                     </p>
#                     <ul class="ocha-links-list">
#                       <li>
#                         <a href="https://interagencystandingcommittee.org/" target="_blank" data-module="hdx_click_stopper" data-module-link_type="header">Inter-Agency Standing Committee</a>
#                       </li>
#                       <li>
#                         <a href="https://www.unocha.org" target="_blank" data-module="hdx_click_stopper" data-module-link_type="header">OCHA Website</a>
#                       </li>
#                       <li>
#                         <a href="https://reliefweb.int" target="_blank" data-module="hdx_click_stopper" data-module-link_type="header">Relief Web</a>
#                       </li>
#                       <li>
#                         <a href="https://vosocc.unocha.org/" target="_blank" data-module="hdx_click_stopper" data-module-link_type="header">Virtual OSOCC</a>
#                       </li>
#                     </ul>
#                   </div>
#                   <div class="col-md-3 col-xs-12">
#                     <a href="https://www.unocha.org/ocha-digital-services" target="_blank" data-module="hdx_click_stopper" data-module-link_type="header" class="btn ocha-see-all">
#                       See all
#                     </a>
#                   </div>
#                 </div>
#               </div>
#
#             </div>
#
#             <div class="header-user-box pull-right">
#
#               <ul class="separated-list">
#
# <!--                 <li>
#                   <a class="action-red" href="/faqs/covid" data-module="hdx_click_stopper" data-module-link_type="footer" aria-label="faq link">
#                     <span class="action-text">
#                       <span class="full-text">Data Responsibility for </span>COVID-19
#                     </span>
#                   </a>
#                 </li> -->
#                 <li>
#                   <a class="action" href="/faq" data-module="hdx_click_stopper" data-module-link_type="footer" aria-label="faq link">
#                     <svg class="icon-o-help" viewBox="0 0 48 48"><path d="M29,43a5,5,0,0,1-5,5,5,5,0,1,1,3.53-8.53A4.82,4.82,0,0,1,29,43Z"/><path d="M24,0A11,11,0,0,0,13,11a4,4,0,0,0,8,0,3,3,0,0,1,6,0h0c0,2-.64,3-2.33,4.67-2,2-4.67,4.67-4.67,9.33v5a4,4,0,0,0,8,0V25c0-1.23.64-2,2.33-3.67A14.43,14.43,0,0,0,35,11h0A11,11,0,0,0,24,0Z"/></svg>
#                     <span class="action-text">
#                       FAQ
#                     </span>
#                   </a>
#                 </li>
#
#
#
#                       <li>
#                         <a class="action" class="special-menuitem" onclick="showOnboardingWidget('#loginPopup');"
#                            href="#" aria-label="login">
#                           <svg class="icon-o-user" viewBox="0 0 48 48">
#                             <path d="M23,24h2A16,16,0,0,1,41,40v4a0,0,0,0,1,0,0H7a0,0,0,0,1,0,0V40A16,16,0,0,1,23,24Z"/>
#                             <rect x="15" y="4" width="18" height="18" rx="9" ry="9"/>
#                           </svg>
#                           <span class="action-text">
#                           Log in
#                         </span>
#
#                         </a>
#                       </li>
#                       <li>
#                         <a class="action" onclick="spawnRecaptcha('#signupPopup');showOnboardingWidget('#signupPopup');"
#                            href="#" aria-label="sign up">
#                           <svg class="icon-o-checked" viewBox="0 0 48 48">
#                             <path
#                               d="M24,2A22,22,0,1,0,46,24,22,22,0,0,0,24,2ZM38.06,18.37,23,33.83a2.92,2.92,0,0,1-2.9.8,3,3,0,0,1-1.6-.83L10,25.29A3,3,0,0,1,14.2,21l6.5,6.5L33.77,14.17a3,3,0,1,1,4.29,4.19Z"/>
#                           </svg>
#                           <span class="action-text">
#                             Sign up
#                           </span>
#                         </a>
#                       </li>
#
#
#
#
#                 <li class="less-important">
#                   <a class="action" href="/m/dataset/wfp-food-prices-for-angola?force_layout=light">
#                     <span class="single-icon icon-phone"></span>
#                     <span>Switch to HDX Lite</span>
#                   </a>
#                 </li>
#
#
#
#               </ul>
#             </div>
#           </div>
#         </div>
#       </div>
#
#     </div>
# </div>
#     <div class="hdx-header">
#     <div class="container">
#         <div class="navbar-header">
#           <div class="hdxLogo">
#               <a class="logo" href="/" aria-label="Humanitarian Data Exchange Logo"><div class="logo-img"></div><span id="hdxVersion">v1.72.6 PY3</span></a>
#           </div>
#           <div class="header-nav-search table-valign pull-left">
#             <div id="previous-searches" style="display: none;">
#                 []
#             </div>
#             <form class="header-search-form" method="get" action="/search?sort=metadata_modified+desc">
#               <div id="input-search">
#                 <div class="header-search-group input-prepend input-append">
#                   <i class="humanitarianicons-Search"></i>
#                   <input type="text" class="searchInput" id="qMobile" name="q" value="" autocomplete="off" placeholder="Search Datasets" aria-label="Search Datasets">
#                   <input type="hidden" value="main-nav" name="ext_search_source" />
#                 </div>
#                 <div class="search-ahead"></div>
#               </div>
#             </form>
#           </div>
#             <button type="button" class="navbar-toggle collapsed" data-toggle="collapse" data-target="#bs-example-navbar-collapse-1">
#                 <span class="sr-only">Toggle navigation</span>
#                 <span class="icon-bar"></span>
#                 <span class="icon-bar"></span>
#             </button>
#
#             <ul class="mainLinks">
#
#             <li><a href="/dataset" data-module="hdx_click_stopper" data-module-link_type="main nav">Data</a></li>
#             <li><a href="/group" data-module="hdx_click_stopper" data-module-link_type="main nav">Locations</a></li>
#             <li><a href="/organization" data-module="hdx_click_stopper" data-module-link_type="main nav">Organisations</a></li>
#             <li style="position: relative">
#               <a href="#" data-toggle="dropdown" aria-haspopup="true" role="button" aria-expanded="false">
#                 <span id="crises-label" >Dataviz <i class="humanitarianicons-Down"></i></span>
#               </a>
#               <ul class="dropdown-menu crises-menu" role="menu" aria-labelledby="crises-label">
#                 <li class="crises-group">
#
#                   <ul>
#
#                     <li>
#                       <div><a href="/event/morocco-earthquake" data-module="hdx_click_stopper" data-module-link_type="main nav" target="_self">
#                         Morroco Earthquake</a></div>
#                       <!--<div class="crises-datasets">[ ## Datasets ]</div>-->
#                     </li>
#
#                     <li>
#                       <div><a href="/cod" data-module="hdx_click_stopper" data-module-link_type="main nav" target="_self">
#                         Common Operational Datasets (CODs)</a></div>
#                       <!--<div class="crises-datasets">[ ## Datasets ]</div>-->
#                     </li>
#
#                     <li>
#                       <div><a href="/dashboards/overview-of-data-grids" data-module="hdx_click_stopper" data-module-link_type="main nav" target="_self">
#                         Data Grids</a></div>
#                       <!--<div class="crises-datasets">[ ## Datasets ]</div>-->
#                     </li>
#
#                     <li>
#                       <div><a href="/dataviz-gallery" data-module="hdx_click_stopper" data-module-link_type="main nav" target="_self">
#                         Dataviz Gallery</a></div>
#                       <!--<div class="crises-datasets">[ ## Datasets ]</div>-->
#                     </li>
#
#                     <li>
#                       <div><a href="/dataviz-guide/" data-module="hdx_click_stopper" data-module-link_type="main nav" target="_blank">
#                         HDX Dataviz Guidelines</a></div>
#                       <!--<div class="crises-datasets">[ ## Datasets ]</div>-->
#                     </li>
#
#                     <li>
#                       <div><a href="/visualization/horn-of-africa-humanitarian-operations/" data-module="hdx_click_stopper" data-module-link_type="main nav" target="_blank">
#                         Horn of Africa Drought Data Explorer</a></div>
#                       <!--<div class="crises-datasets">[ ## Datasets ]</div>-->
#                     </li>
#
#                     <li>
#                       <div><a href="/visualization/ukraine-humanitarian-operations/" data-module="hdx_click_stopper" data-module-link_type="main nav" target="_self">
#                         Ukraine Data Explorer</a></div>
#                       <!--<div class="crises-datasets">[ ## Datasets ]</div>-->
#                     </li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                   </ul>
#                 </li>
#
#                 <li class="crises-group">
#
#                   <a class="archive" href="/archive" data-module="hdx_click_stopper" data-module-link_type="main nav">Archived <i class="icon humanitarianicons-Out-of-platform"></i></a>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 </li>
#
#               </ul>
#             </li>
#
#           </ul>
#             <span class="submit-data contribute-popup-init" dataset-id="DO_IGNORE">
#
#
#                     <a href="/contribute" onclick=""
#                        data-module="hdx_click_stopper" data-module-link_type="header add data">
#
#                   <div class="submitData">
#                     Add data
#                   </div>
#                 </a>
#             </span>
#         </div>
#
#         <!-- Collect the nav links, forms, and other content for toggling -->
#         <div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1">
#             <ul class="nav navbar-nav">
#                 <li><a href="/dataset" data-module="hdx_click_stopper" data-module-link_type="main nav">Data</a></li>
#                 <li><a href="/group" data-module="hdx_click_stopper" data-module-link_type="main nav">Locations</a></li>
#                 <li><a href="/organization" data-module="hdx_click_stopper" data-module-link_type="main nav">Organisations</a></li>
#                 <li class="crisis"><a class="crisis-title"><span>Dataviz</span></a></li>
#
#
#                   <li class="crisis"><a href="/event/morocco-earthquake" data-module="hdx_click_stopper" data-module-link_type="main nav" target="_self">Morroco Earthquake</a></li>
#
#                   <li class="crisis"><a href="/cod" data-module="hdx_click_stopper" data-module-link_type="main nav" target="_self">Common Operational Datasets (CODs)</a></li>
#
#                   <li class="crisis"><a href="/dashboards/overview-of-data-grids" data-module="hdx_click_stopper" data-module-link_type="main nav" target="_self">Data Grids</a></li>
#
#                   <li class="crisis"><a href="/dataviz-gallery" data-module="hdx_click_stopper" data-module-link_type="main nav" target="_self">Dataviz Gallery</a></li>
#
#                   <li class="crisis"><a href="/dataviz-guide/" data-module="hdx_click_stopper" data-module-link_type="main nav" target="_blank">HDX Dataviz Guidelines</a></li>
#
#                   <li class="crisis"><a href="/visualization/horn-of-africa-humanitarian-operations/" data-module="hdx_click_stopper" data-module-link_type="main nav" target="_blank">Horn of Africa Drought Data Explorer</a></li>
#
#                   <li class="crisis"><a href="/visualization/ukraine-humanitarian-operations/" data-module="hdx_click_stopper" data-module-link_type="main nav" target="_self">Ukraine Data Explorer</a></li>
#
#
#
#
#
#
#
#
#
#                 <li class="crisis"><a href="/archive" class="crisis-title"><span>Dataviz / Archived</span></a></li>
#
#
#
#                 <li class="sub-nav"><a href="/faq" data-module="hdx_click_stopper" data-module-link_type="main nav">FAQ</a></li>
# <!--                 <li class="sub-nav"><a class="action-red" href="/faqs/covid" data-module="hdx_click_stopper" data-module-link_type="main nav"><span class="full-text">Data Responsibility for </span>COVID-19</a></li> -->
#
#
#                 <li class="sub-nav login top-pad">
#                   <a onclick="showOnboardingWidget('#loginPopup');" href="#" aria-label="login">Login</a> |
#                   <a onclick="showOnboardingWidget('#signupPopup');" href="#" aria-label="sign up">Sign up</a>
#                 </li>
#             </ul>
#         </div>
#     </div>
#     </div>
# </nav>
# <!-- MOBILE NAV END -->
#
#         </div>
#       </div>
#
#
#       <div role="main">
#         <div id="content" class="container">
#
#
#               <div class="container">
#                 <div class="row paddingRowHack toolbarRow">
#                   <div class="col-xs-12 paddingLeftHack paddingRightHack">
#                     <div class="pull-left">
#                       <div class="toolbar">
#
#
#                             <ol class="breadcrumb" vocab="https://schema.org/" typeof="BreadcrumbList">
#
# <li class="home" property="itemListElement" typeof="ListItem">
#   <a href="/" property="item" typeof="WebPage">
#     <span property="name">Home</span>
#   </a>
#   <meta property="position" content="1">
# </li>
#
#
#
# <li property="itemListElement" typeof="ListItem">
#   <a href="/dataset" property="item" typeof="WebPage">
#     <span property="name">Datasets</span>
#   </a>
#   <meta property="position" content="2">
# </li>
#
#   <li class="active"><a href="/dataset/wfp-food-prices-for-angola">Angola - Food Prices</a></li>
#
#
#                             </ol>
#
#
#                       </div>
#                     </div>
#                   </div>
#                 </div>
#               </div>
#
#
#
#               <div class="paddingRowHack">
#
#               </div>
#
#
#             <div class="container mainContent">
#
#               <div class="hdx-wrapper wrapper">
#
#
#                   <div class="row paddingRowHack contentBackground">
#                     <div class="col-xs-12 paddingLeftHack paddingRightHack">
#
# <div class="row paddingRowHack whiteBackground">
#
#
#
#     <div class="col-xs-12 paddingLeftHack paddingRightHack ">
#         <div class="row">
#             <div class="col-xs-8 ">
#                 <div class="row">
#                     <div class="col-xs-12 mTop35 mBottom30" >
#                         <h1 class="itemTitle dataset-title">
#                             Angola - Food Prices
#
#
#
#                         </h1>
#                     </div>
#                 </div>
#
#
#                 <div class="row mBottom15">
#                     <div class="col-xs-12" >
#
#                         <div data-module="hdx_show_more" style="visibility:hidden" class="notes embedded-content">
#                             <p>This dataset contains Food Prices data for Angola, sourced from the World Food Programme Price Database. The World Food Programme Price Database covers foods such as maize, rice, beans, fish, and sugar for 98 countries and some 3000 markets. It is updated weekly but contains to a large extent monthly data. The data goes back as far as 1992 for a few countries, although many countries started reporting from 2003 or thereafter.</p>
#                         </div>
#
#                     </div>
#                 </div>
#             </div>
#             <div class="col-xs-4 mTop35">
#
#
#
#
#                 <div class="org-logo-large" style="width: 100%;">
#
#                     <a href="/organization/wfp">
#                       <img class="org-logo lazyload" data-src="/image/20150514-073819.260300wfp.png" alt="WFP - World Food Programme"/>
#                     </a>
#
#                 </div>
#
#             </div>
#             <div class="col-xs-12 align-bottom-right mTop20 mBottom15">
#                 <ul class="pull-left dataset-resources ">
#
#
#
#
#
#
#   <li class="label-icons">
#
#
#
#
#
#
#
#
#       <span class="humanitarianicons-Copy" title="Showcase Item" data-module="bs_tooltip" data-module-placement="top" data-toggle="tooltip"  ></span>
#
#
#       <span class="humanitarianicons-Staff-management" title="Sub-national Data" data-module="bs_tooltip" data-module-placement="top" data-toggle="tooltip"  ></span>
#
#
#
#
#
#     <a href="/dataset?ext_hxl=1">
#       <span class="icon-hxl-tags" title="Dataset Containing HXL Tags" data-module="bs_tooltip"
#             data-module-placement="top" data-toggle="tooltip">
#       </span>
#     </a>
#
#
#     <a href="/dataset?ext_quickcharts=1">
#         <span class="humanitarianicons-Chart" title="Dataset Containing Quick Charts" data-module="bs_tooltip"
#               data-module-placement="top" data-toggle="tooltip"></span>
#     </a>
#
#
#
#
#   </li>
#
#
#
#
#     <li class="label-icons"><span class="download-counts" title="Total number of downloads" data-module="bs_tooltip" data-module-placement="top" data-toggle="tooltip">800+ Downloads </span></li>
#
#
#
#     <li class="label-icons">
#       <span class="download-counts">This dataset updates: As needed</span>
#
#     </li>
#
#
#
#
#
#
#
#                 </ul>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div id="contactContributorPopup" class="popup popup-onboarding" style="display: none;" >
#     <div class="content  container-fluid">
#
#     <div class="row two-column-widget two-column-select-organisation">
#         <div class="two-column-left col-sm-6 col-xs-12">
#
#     <div>
#         <div class="large-title">Contact the Contributor</div>
#         <div class="mTop20 large-text">Use the form to ask a question or provide comments about this dataset to the contributor.</div>
#         <div class="mTop20 regular-text">
#             HDX feedback will be blind copied on this message so that we are aware of the initial correspondence related to datasets on the HDX site. Please  &nbsp;<a href="https://centre.humdata.org/contact-us/">contact us</a>&nbsp; directly should you need further support.
#         </div>
#     </div>
#
#         </div>
#         <div class="two-column-right col-sm-6 col-xs-12">
#
#     <div id="contact-contributor">
#         <form id="contact-contributor-form">
#             <div class="row" style="overflow-y: auto; height: 400px;">
#                 <div class="col-xs-12">
#                     <div class="bold-regular-text" title="Angola - Food Prices" data-module="bs_tooltip" data-module-placement="bottom" data-toggle="tooltip">
#                         [Dataset] <span class="contact-popup-title">Angola - Food Prices</span>
#                         <input type="hidden" name="pkg_title" value="">
#                         <input type="hidden" name="pkg_owner_org" value="">
#                         <input type="hidden" name="pkg_id" value="">
#                     </div>
#                     <select class="required mTop15" id="contact-contributor-topics-selector" name="topic" required="required">
#                         <option id="" value="">Your inquiry is regarding ...</option>
#
#                             <option id="contact-contributor-general question" value="general question">General question</option>
#
#                             <option id="contact-contributor-metadata" value="metadata">Metadata</option>
#
#                             <option id="contact-contributor-problem report" value="problem report">Problem report</option>
#
#                             <option id="contact-contributor-suggested edits" value="suggested edits">Suggested edits</option>
#
#                     </select>
#                     <div class="mTop15 control">
#                         <input id="contact-contributor-fullname" name="fullname" required="required" class="full-width required " type="text" value="">
#                         <label for="contact-contributor-fullname">Your name</label>
#                     </div>
#                     <div class="mTop15 control">
#                         <input id="contact-contributor-email" name="email" required="required" class="full-width required " type="text" value="">
#                         <label for="contact-contributor-email">Your email address</label>
#                     </div>
#                     <div class="mTop15 control">
#                         <textarea id="contact-contributor-msg" name="msg" class="full-width required" required="required"></textarea>
#                         <label for="contact-contributor-msg">Comments</label>
#                     </div>
#                 </div>
#             </div>
#             <div class="right-side-actions">
#                 <input class="btn btn-empty btn-empty-black btn-large" type="button" onclick="closeCurrentWidget(this);" value="Cancel">
#                 <input id="submitContactContributorMessage" class="btn btn-primary btn-large mL45 hdx-recaptcha" disabled type="submit" value="Submit" data-sitekey="6Lcl60EUAAAAAE46a3XcPM2nPUKI2K4XZbcsorkR" data-callback="contactContributorOnSubmit" data-size="invisible" data-badge="inline">
#             </div>
#         </form>
#     </div>
#
#             <div class="right-side-actions">
#
#
#             </div>
#         </div>
#     </div>
#
#     </div>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div id="groupMessagePopup" class="popup popup-onboarding" style="display: none;" >
#     <div class="content  container-fluid">
#
#     <div class="row two-column-widget two-column-select-organisation">
#         <div class="two-column-left col-sm-6 col-xs-12">
#
#     <div>
#         <div class="large-title">Group Message</div>
#         <div class="mTop20 large-text">
#             Use group message to communicate and collaborate with other members of your organisation.
#         </div>
#         <div class="mTop20 regular-text">
#             This feature is available for datasets shared publicly or privately by your organisation. It is not visible to anyone outside of your organisation.<br/>
#         </div>
#     </div>
#
#         </div>
#         <div class="two-column-right col-sm-6 col-xs-12">
#
#     <div id="group-message">
#         <form id="group-message-form">
#             <div class="alert alert-danger hide"></div>
#             <div class="row" style="overflow-y: auto; height: 400px;">
#                 <div class="col-xs-12">
#                     <div class="bold-regular-text" title="Angola - Food Prices" data-module="bs_tooltip" data-module-placement="bottom" data-toggle="tooltip">
#                         [DATASET] Angola - Food Prices
#                         <input type="hidden" name="source_type" value="dataset">
#                         <input type="hidden" name="title" value="Angola - Food Prices">
#                         <input type="hidden" name="org_id" value="3ecac442-7fed-448d-8f78-b385ef6f84e7">
#                         <input type="hidden" name="pkg_id" value="wfp-food-prices-for-angola">
#                     </div>
#                     <select class="required mTop15" id="group-message-topics-selector" name="topic" required="required" onchange="_groupMessageValidator();">
#                         <option id="" value="">Select recipient group(s)</option>
#
#                     </select>
#                     <div class="mTop15 control">
#                         <input id="group-message-fullname" name="fullname" class="full-width required" type="text" value="">
# ...
#                       <div class="mailChimpForm">
#                         <div class="subscribeText">Subscribe to our mailing list</div>
#                         <!-- Begin MailChimp Signup Form -->
#                         <div id="mc_embed_signup">
#                           <form action="//humdata.us14.list-manage.com/subscribe/post?u=ea3f905d50ea939780139789d&amp;id=99796325d1" method="post" id="mc-embedded-subscribe-form" name="mc-embedded-subscribe-form" class="validate" target="_blank" novalidate="" _lpchecked="1">
#
#                             <div class="six columns left" style="padding-left: 0px;">
#                               <input type="email" value="" name="EMAIL" class="email" id="mce-EMAIL" aria-label="email">
#                               <input type="submit" value="Subscribe" name="subscribe" id="mc-embedded-subscribe" class="btn btn-primary">
#                             </div>
#                             <div id="mce-responses" class="clear">
#                               <div class="response" id="mce-error-response" style="display:none"></div>
#                               <div class="response" id="mce-success-response" style="display:none"></div>
#                             </div>    <!-- real people should not fill this in and expect good things - do not remove this or risk form bot signups-->
#                             <!--
#                             <div>
#                               <input type="text" name="b_83487eb1105d72ff2427e4bd7_6fd988326c" tabindex="-1" value="">
#                             </div>
#                             -->
#                             <div class="clear one columns left">
#                             </div>
#                           </form>
#                         </div>
#                         <!--End mc_embed_signup-->
#                       </div>
#                     </div>
#                   </div>
#
#                 </div>
#                 <div class="col-xs-12 col-md-offset-1 col-md-6">
#                   <div class="row">
#                     <div class="col-xs-12">
#                       <div class="titlePlusVersion match-logo-margin mBottom20">
#                         OUR OTHER SERVICES
#                       </div>
#                     </div>
#                     <div class="col-xs-12 col-md-4 other-services">
#                       <a href="https://centre.humdata.org" target="_blank" data-module="hdx_click_stopper" data-module-link_type="footer" aria-label="the centre for humanitarian data">
#                         <img class="lazyload logo-centre" data-src="/images/homepage/logo-centre-gray.png" alt="The Centre for Humanitarian Data logo">
#                       </a>
#                     </div>
#                     <div class="col-xs-12 col-md-4 other-services">
#                       <a href="https://hxlstandard.org/" target="_blank" data-module="hdx_click_stopper" data-module-link_type="footer" aria-label="hxl">
#                         <img class="lazyload logo-hxl" data-src="/images/homepage/logo-hxl.svg" alt="HXL logo">
#                       </a>
#                     </div>
#                   </div>
#                 </div>
#               </div>
#
#               <div>
#
#
#
#               </div>
#             </div>
#         </div>
#       </div>
#     </div>
#
#     <div class="row paddingRowHack" style="background-color: #252525;">
#       <div class="">
#         <div class="">
#           <div class="col-xs-12 paddingLeftHack paddingRightHack">
#             <div class="social-footer">
#               <div class="terms">
#                 <a href="/faqs/terms" data-module="hdx_click_stopper" data-module-link_type="footer">
#                   TERMS OF SERVICE
#                 </a>
#                 <a href="https://data.humdata.org/about/hdx-qa-process" data-module="hdx_click_stopper" data-module-link_type="footer">
#                   QA PROCESS
#                 </a>
#                 <a href="https://github.com/OCHA-DAP" target="_blank" data-module="hdx_click_stopper" data-module-link_type="footer">
#                   OPEN SOURCE <i class="icon humanitarianicons-Out-of-platform"></i>
#                 </a>
#                 <a href="/faqs/devs" data-module="hdx_click_stopper" data-module-link_type="footer">
#                   RESOURCES FOR DEVELOPERS
#                 </a>
#                 <a href="/faqs/licenses" data-module="hdx_click_stopper" data-module-link_type="footer">
#                   DATA LICENSES
#                 </a>
#                 <a href="https://centre.humdata.org/category/blog/" target="_blank" data-module="hdx_click_stopper" data-module-link_type="footer">
#                   BLOG <i class="icon humanitarianicons-Out-of-platform"></i>
#                 </a>
#                 <a href="https://centre.humdata.org/contact-us/" target="_blank" data-module="hdx_click_stopper" data-module-link_type="footer">
#                   CONTACT <i class="icon humanitarianicons-Out-of-platform"></i>
#                 </a>
#                 <span class="separator"></span>
#                 <span class="social-actions">
#                   <a href="https://www.twitter.com/humdata" title="Twitter" target="_blank" data-module="hdx_click_stopper" data-module-link_type="footer">
#                     <i class="humanitarianicons-Social-tw" aria-hidden="true"></i>
#                   </a>
#                   <a href="https://github.com/OCHA-DAP" title="GitHub" target="_blank" data-module="hdx_click_stopper" data-module-link_type="footer">
#                     <i class="humanitarianicons-Social-gh" aria-hidden="true"></i>
#                   </a>
#                 </span>
#               </div>
#               <div class="service">
#                 <div class="provided-by">
#                   Service provided by
#                 </div>
#                 <div class="service-details">
#                   <div class="ocha-service">
#                     <img class="ocha-logo lazyload" data-src="/images/homepage/logo-ocha-lockup-white.png" alt="OCHA logo" />
#                     <div class="spacer"></div>
#                     <div class="ocha-text">
#                       OCHA coordinates the global emergency response to save lives and protect people in humanitarian
#                       crises. We advocate for effective and principled humanitarian action by all, for all.
#                     </div>
#                   </div>
#                   <div class="license-group">
#                     <div class="license">
#                       Except where otherwise noted, content on this site is
#                       licensed under a Creative Commons Attribution 4.0
#                       International license.
#                     </div>
#                     <div class="license-cc">
#                       <svg width="40" height="40" viewBox="0 0 32 32">
#                         <path d="M15.886 28.968c-7.159 0.009-12.857-5.804-12.884-12.802-0.027-7.097 5.847-13.062 12.902-12.881 6.356-0.152 12.793 4.975 12.829 12.839 0.035 7.721-6.201 12.836-12.847 12.844zM15.907 0.254c-9.353-0.056-15.873 7.837-15.907 15.828-0.036 8.503 6.961 15.927 15.827 15.918 8.53-0.009 15.954-6.753 15.885-15.803 0.111-8.79-6.935-15.89-15.805-15.943z"></path>
#                         <path d="M25.263 18.406c-0.958 1.921-3.394 2.767-5.132 2.632-4.489-0.347-5.501-3.918-4.747-6.567 0.701-2.462 3.115-3.831 6.002-3.466 1.667 0.21 2.961 0.886 3.863 2.334-0.818 0.397-1.591 0.773-2.382 1.157-0.165-0.166-0.288-0.268-0.381-0.388-0.535-0.7-1.25-0.982-2.19-0.822-0.93 0.158-1.479 0.714-1.589 1.482-0.117 0.814-0.094 1.668 0.039 2.482 0.126 0.777 0.707 1.336 1.62 1.462 0.99 0.137 1.856-0.059 2.38-0.931 0.065-0.108 0.161-0.201 0.309-0.382 0.728 0.332 1.444 0.658 2.208 1.007z"></path>
#                         <path d="M16.842 13.347c-0.871 0.415-1.613 0.768-2.391 1.138-0.156-0.15-0.304-0.262-0.412-0.4-0.545-0.698-1.269-0.964-2.203-0.797-0.888 0.159-1.44 0.687-1.541 1.432-0.115 0.841-0.101 1.718 0.030 2.557 0.122 0.784 0.725 1.323 1.637 1.444 0.956 0.126 1.8-0.056 2.326-0.887 0.081-0.128 0.193-0.241 0.346-0.43 0.737 0.339 1.452 0.667 2.206 1.014-0.357 0.81-0.978 1.311-1.659 1.759-2.518 1.661-6.749 0.909-7.962-1.851-1.013-2.305-0.422-5.145 1.656-6.505 2.136-1.398 5.664-1.088 7.33 0.691 0.212 0.226 0.376 0.49 0.636 0.834z"></path>
#                       </svg>
#                     </div>
#                   </div>
#                 </div>
#               </div>
#             </div>
#           </div>
#         </div>
#       </div>
#     </div>
#
#   </div>
# </footer>
#
#
#
#
#
#
#
#
#
#
#   <script src="https://www.google.com/recaptcha/api.js" async defer></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   <script type="application/ld+json">
#     {
#     "@context": {
#         "rdf": "http://www.w3.org/1999/02/22-rdf-syntax-ns#",
#         "rdfs": "http://www.w3.org/2000/01/rdf-schema#",
#         "schema": "http://schema.org/",
#         "xsd": "http://www.w3.org/2001/XMLSchema#"
#     },
#     "@graph": [
#         {
#             "@id": "https://data.humdata.org/dataset/f6155f17-bded-468c-b926-b9de5034d2ad",
#             "@type": "schema:Dataset",
#             "schema:about": {
#                 "@id": "_:Nd852c738ea3944cc8ff6f7e1098fe76b"
#             },
#             "schema:dateModified": "2023-09-12T04:40:52.635443",
#             "schema:datePublished": "2018-10-21T08:01:03.714409",
#             "schema:description": "This dataset contains Food Prices data for Angola, sourced from the World Food Programme Price Database. The World Food Programme Price Database covers foods such as maize, rice, beans, fish, and sugar for 98 countries and some 3000 markets. It is updated weekly but contains to a large extent monthly data. The data goes back as far as 1992 for a few countries, although many countries started reporting from 2003 or thereafter.",
#             "schema:distribution": [
#                 {
#                     "@id": "https://data.humdata.org/dataset/f6155f17-bded-468c-b926-b9de5034d2ad/resource/34592b8d-921a-4841-b258-4e21f4c25e7e"
#                 },
#                 {
#                     "@id": "https://data.humdata.org/dataset/f6155f17-bded-468c-b926-b9de5034d2ad/resource/8d87dc41-26b9-4928-86ec-75f95480e18d"
#                 }
#             ],
#             "schema:includedInDataCatalog": {
#                 "@id": "_:N8b726431abfb452ca28e96e00d0275b0"
#             },
#             "schema:keywords": [
#                 "markets",
#                 "food security",
#                 "economics",
#                 "hxl",
#                 "indicators"
#             ],
#             "schema:license": "http://creativecommons.org/licenses/by/3.0/igo/legalcode",
#             "schema:name": "Angola - Food Prices",
#             "schema:publisher": {
#                 "@id": "https://data.humdata.org/organization/3ecac442-7fed-448d-8f78-b385ef6f84e7"
#             },
#             "schema:url": "https://data.humdata.org/dataset/wfp-food-prices-for-angola"
#         },
#         {
#             "@id": "_:N8b726431abfb452ca28e96e00d0275b0",
#             "@type": "schema:DataCatalog",
#             "schema:description": "",
#             "schema:name": "Humanitarian Data Exchange",
#             "schema:url": "https://data.humdata.org"
#         },
#         {
#             "@id": "_:Nd852c738ea3944cc8ff6f7e1098fe76b",
#             "@type": "schema:Thing",
#             "schema:name": "ago",
#             "schema:url": "https://data.humdata.org/group/ago"
#         },
#         {
#             "@id": "https://data.humdata.org/organization/3ecac442-7fed-448d-8f78-b385ef6f84e7",
#             "@type": "schema:Organization",
#             "schema:contactPoint": {
#                 "@id": "_:N20522a1753fa46ab8dff08762acd52ff"
#             },
#             "schema:name": "WFP - World Food Programme"
#         },
#         {
#             "@id": "_:N20522a1753fa46ab8dff08762acd52ff",
#             "@type": "schema:ContactPoint",
#             "schema:contactType": "customer service",
#             "schema:name": "f1921552-8c3e-47e9-9804-579b14a83ee3",
#             "schema:url": "https://data.humdata.org"
#         },
#         {
#             "@id": "https://data.humdata.org/dataset/f6155f17-bded-468c-b926-b9de5034d2ad/resource/8d87dc41-26b9-4928-86ec-75f95480e18d",
#             "@type": "schema:DataDownload",
#             "schema:contentSize": 162784,
#             "schema:contentUrl": "https://data.humdata.org/dataset/f6155f17-bded-468c-b926-b9de5034d2ad/resource/8d87dc41-26b9-4928-86ec-75f95480e18d/download/wfp_food_prices_ago.csv",
#             "schema:description": "Food prices data with HXL tags",
#             "schema:encodingFormat": "CSV",
#             "schema:name": "Angola - Food Prices"
#         },
#         {
#             "@id": "https://data.humdata.org/dataset/f6155f17-bded-468c-b926-b9de5034d2ad/resource/34592b8d-921a-4841-b258-4e21f4c25e7e",
#             "@type": "schema:DataDownload",
#             "schema:contentSize": 12075,
#             "schema:contentUrl": "https://data.humdata.org/dataset/f6155f17-bded-468c-b926-b9de5034d2ad/resource/34592b8d-921a-4841-b258-4e21f4c25e7e/download/wfp_food_prices_ago_qc.csv",
#             "schema:description": "Food prices QuickCharts data with HXL tags",
#             "schema:encodingFormat": "CSV",
#             "schema:name": "QuickCharts: Angola - Food Prices"
#         }
#     ]
# }
#   </script>
#
#
#
#
#
#
#
#
#
#
#
#
#     <link href="/webassets/ckanext-hdx_theme/2236c8e6_onboarding-password-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/bb4a54e2_onboarding-done-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/1b4f7baa_search-styles.css" rel="stylesheet"/>
# <link href="/webassets/ckanext-hdx_theme/f6cadab7_popup-hxl-styles.css" rel="stylesheet"/>
#     <script src="/webassets/vendor/d8ae4bed_jquery.js" type="text/javascript"></script>
# <script src="/webassets/vendor/fb6095a0_vendor.js" type="text/javascript"></script>
# <script src="/webassets/vendor/580fa18d_bootstrap.js" type="text/javascript"></script>
# <script src="/webassets/base/15a18f6c_main.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/b56baf8a_ckan.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/7684e53b_contact-contributor-scripts.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/10d00ede_group-message-scripts.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/a3e44857_requestdata-scripts.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/48b5399d_jquery-extra.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/5114efd8_hdx-show-more.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/dde5b6f3_resource-list-scripts.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/f1474f59_banner-scripts.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/65caaee1_page-scripts.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/4e1bbb01_search-scripts.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/97eb9915_onboarding-scripts.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/849bf566_onboarding-password-scripts.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/1b105df9_charting-scripts.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/6451be2c_dataset-scripts.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/1d8ed741_dataset-quick-edit-scripts.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/6400b206_resource-hdx-autocomplete.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_hxl_preview/4d8b4b19_page-scripts.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/ef069373_popup-scripts.js" type="text/javascript"></script>
# <script src="/webassets/ckanext-hdx_theme/b66c3178_popup-hxl-scripts.js" type="text/javascript"></script>
#   </body>
#
#
# </html>

# %%
soup=BeautifulSoup(page) # turn page content into soup
for link in soup.find_all('a'): # loop through all links
    csv_link=str(link.get('href')) # turn links into strings
    if csv_link.endswith('csv') and ('wfp_food_prices' in csv_link) and ('qc' not in csv_link): #select links that meet the conditions
        print(csv_link)
# Out:
# /dataset/f6155f17-bded-468c-b926-b9de5034d2ad/resource/8d87dc41-26b9-4928-86ec-75f95480e18d/download/wfp_food_prices_ago.csv

# %%
# Now I can create a loop to collect all 99 csv links I need to download the data

final_list=[]   # create a list to collect all the links

for i in url_list: # code has to loop through each of 99 links on the url_list
    page_content=requests.get(i).text # turns the content of the page into text
    soup=BeautifulSoup(page_content) # turns content into soup
    for link in soup.find_all('a'): # now it needs to loop through every link on the page
        csv_link=str(link.get('href')) # if the link meets the criteria: ends with .csv, contains 'wfp_food_prices' and doesn't contain 'qc'
        if csv_link.endswith('csv') and ('wfp_food_prices' in csv_link) and ('qc' not in csv_link): 
            final_list.append(csv_link) #link gets appended to the list
    print(final_list)
# Out:
# ['/dataset/a246cbac-42d5-47b2-ba75-ac66f69e83de/resource/03e6ce5d-03a2-4e60-8d04-afa39c5972f4/download/wfp_food_prices_afg.csv', '/dataset/f6155f17-bded-468c-b926-b9de5034d2ad/resource/8d87dc41-26b9-4928-86ec-75f95480e18d/download/wfp_food_prices_ago.csv', '/dataset/49dc23aa-dd97-4985-adaf-b79f1c6ec0f4/resource/ea099434-3274-4314-800b-41458d1e9746/download/wfp_food_prices_arg.csv', '/dataset/605f01e2-32a3-4d94-a718-0c79c4c613ff/resource/0798b658-a35d-42c7-bc37-84b28e6d8410/download/wfp_food_prices_arm.csv', '/dataset/79dc8689-3d66-4f4e-b95a-64dd7acd763f/resource/e78439c2-5e3f-4988-b751-bb758f1c6dc3/download/wfp_food_prices_aze.csv', '/dataset/e7e5df38-adb6-4843-a053-24e119b27afc/resource/efa227dd-2fd5-437e-b79d-130af02b769d/download/wfp_food_prices_bdi.csv', '/dataset/66c7d54e-0c3b-45e5-9a46-07ea6f195093/resource/7da1ea0a-56c7-450a-af2c-d477745fc856/download/wfp_food_prices_ben.csv', '/dataset/bfd82e1f-0296-48a8-ac28-c11e028be5ed/resource/0eca67d6-e297-4f5e-9132-7dc42891b749/download/wfp_food_prices_bfa.csv', '/dataset/c76eabb7-fdb5-43b7-a5c4-09091bb8acde/resource/966ab7ac-56d6-4dac-8eba-dfe815d59a52/download/wfp_food_prices_bgd.csv', '/dataset/4eba44c4-8a10-4504-b3a1-7a38dad478ac/resource/4a993a46-e5f7-49a9-a471-6a24d343e739/download/wfp_food_prices_blr.csv', '/dataset/6cced040-794e-47cb-8c1f-3b41c8e2af45/resource/042a6d68-ea6d-4f1b-a0db-6cfed1c52ee4/download/wfp_food_prices_bol.csv', '/dataset/967b2400-784b-4a95-a9d6-dacc16f78c22/resource/c8f97ebe-278c-4377-a532-8ed740b1ceb7/download/wfp_food_prices_btn.csv', '/dataset/e9f27b34-f511-498c-a7f8-fe8d2321f7ba/resource/cb558a54-357a-4bcd-9edd-30caf65b1bd7/download/wfp_food_prices_caf.csv', '/dataset/687d0bdf-5bdf-46d9-9d56-1a333932e2a5/resource/bbe3872b-56ab-442d-8209-6b5e3a8b99e5/download/wfp_food_prices_chn.csv', '/dataset/e6ff12e6-0670-4a0e-af9f-3750688e6c8d/resource/b54849f9-d90f-48cb-b818-8ea5b60306d5/download/wfp_food_prices_civ.csv', '/dataset/f6ed9f06-36b9-43b2-97f3-fc0b8e16d155/resource/9deec824-1e42-4a91-b704-b73fd250ec5a/download/wfp_food_prices_cmr.csv', '/dataset/07a6d6fb-828d-4391-afb8-78b1fc32caa3/resource/c9906fd4-9947-450a-b816-682907463f2a/download/wfp_food_prices_cod.csv', '/dataset/86dfc591-9de6-44f8-b908-ebba34a96ddf/resource/21bf778a-2cdd-4ca2-b017-9779534d3281/download/wfp_food_prices_cog.csv', '/dataset/dd6f3c15-69c0-44c0-8f62-6c5395dcc572/resource/c99063c7-016c-4eef-89dd-9a88db15ad7c/download/wfp_food_prices_col.csv', '/dataset/f9f8ff96-61eb-472e-9ec8-814980cfabcd/resource/0894fd0b-53b3-41f5-8897-17c05bc003c7/download/wfp_food_prices_cpv.csv', '/dataset/802beab1-f195-4739-998d-db7e1c486a82/resource/e216dc16-059e-4cb9-be0c-6fe04f375bd5/download/wfp_food_prices_cri.csv', '/dataset/b9e4ffde-205c-4887-beb0-a1fa027e8bdc/resource/1e404d41-2300-4d0b-ba1c-730f55cb58aa/download/wfp_food_prices_dji.csv', '/dataset/e5d8459f-f7f4-4364-878c-2f14b5e534de/resource/5130ba8c-cb6f-412a-a300-6d731678409c/download/wfp_food_prices_dom.csv', '/dataset/6ca04cee-665a-4037-b04e-b94a8b2cdef9/resource/ede2e94c-5550-45c8-aac1-5267d65b04c7/download/wfp_food_prices_dza.csv', '/dataset/111bd135-8f22-4f0e-9917-3f0d040a1c82/resource/cfea5b70-e50b-44e2-9728-de735af134a8/download/wfp_food_prices_ecu.csv', '/dataset/230e991f-3438-4763-8044-e424b5a67bec/resource/561cea27-29af-40b8-bf3f-633c734cecb2/download/wfp_food_prices_egy.csv', '/dataset/4702c45e-cd9e-4e85-aab3-ef506a946a10/resource/075cdb63-d84f-43b8-9dc6-603aeea184b3/download/wfp_food_prices_eri.csv', '/dataset/2e4f1922-e446-4b57-a98a-d0e2d5e34afa/resource/87bac18e-f3aa-4b29-8cf8-76763e823dc5/download/wfp_food_prices_eth.csv', '/dataset/4f810b15-82f1-4ae3-a380-d6ab50cd9cd1/resource/d365efdc-3519-45d5-b244-2285ae5649d3/download/wfp_food_prices_fji.csv', '/dataset/423e0a51-bb5f-4ce8-b269-f0d9319cd8a5/resource/1a1dc63e-448f-4ce7-a409-9d3bb923b0f8/download/wfp_food_prices_gab.csv', '/dataset/c7ec36bd-baad-4212-a8b7-4bc99c77d005/resource/acee33f1-f971-4d7a-aff5-7cefdfad8e10/download/wfp_food_prices_geo.csv', '/dataset/626e809c-c4fc-467b-a6 ...

# %%
# saving the list in case I might need it later

file=open('csv_links.txt','w') # creating a new file to write down all links
for item in final_list:
    file.write('https://data.humdata.org/'+item+'\n') #write each link in the text file
file.close()

# %% [markdown]
# <a id='download'></a>
# ## Downloading the files
# [Back to top](#top)

# %%
# I want to figure out how to extract country iso code from the link so I can use it as the name of the file while downloading

url='/dataset/f6155f17-bded-468c-b926-b9de5034d2ad/resource/8d87dc41-26b9-4928-86ec-75f95480e18d/download/wfp_food_prices_ago.csv'
name=url.rsplit('_',1)
name[-1].strip()
# Out:
# 'ago.csv'

# %%
# Now I want to use the links to download the data. First, I try with one link

base_link='https://data.humdata.org/'
url='/dataset/f6155f17-bded-468c-b926-b9de5034d2ad/resource/8d87dc41-26b9-4928-86ec-75f95480e18d/download/wfp_food_prices_ago.csv'
url_list=url.rsplit('_',1)
filename=url_list[-1].strip()
urllib.request.urlretrieve(base_link+url,os.path.join(path,name))
# Out:
# ('C:\\Users\\frauz\\Documents\\Python Projects\\Final Project\\Data\\ago.csv',
#  <http.client.HTTPMessage at 0x197d5a14c10>)

# %%
# before I try to loop through 99 links, I want to tra with just 3
test_list=final_list[:3] # creating a sub-list to test the loop first
test_list
# Out:
# ['/dataset/a246cbac-42d5-47b2-ba75-ac66f69e83de/resource/03e6ce5d-03a2-4e60-8d04-afa39c5972f4/download/wfp_food_prices_afg.csv',
#  '/dataset/f6155f17-bded-468c-b926-b9de5034d2ad/resource/8d87dc41-26b9-4928-86ec-75f95480e18d/download/wfp_food_prices_ago.csv',
#  '/dataset/49dc23aa-dd97-4985-adaf-b79f1c6ec0f4/resource/ea099434-3274-4314-800b-41458d1e9746/download/wfp_food_prices_arg.csv']

# %%
# Now I try to download 3 files
base_link='https://data.humdata.org/'
for url in test_list:
    url_list=url.rsplit('_',1)
    name=url_list[-1].strip()
    file = open(name, "w")
    urllib.request.urlretrieve(base_link+url, os.path.join(path, name))
    file.close

# %%
# It's time to download the rest of the files

rest_list=final_list[3:]
len(rest_list)
# Out:
# 96

# %%
 base_link='https://data.humdata.org/'
for url in rest_list:
    url_list=url.rsplit('_',1)
    name=url_list[-1].strip()
    file = open(name, "w")
    urllib.request.urlretrieve(base_link+url, os.path.join(path, name))
    file.close

# %% [markdown]
# <a id='concat'></a>
# ## Combining the files into a single data set
# [Back to top](#top)

# %%
# let's import one data set and check its structure

df_afg=pd.read_csv(os.path.join(path, 'afg.csv'), index_col=False)

# %%
col_list=df_afg.columns.to_list()

# %%
# Now I want to combine the 99 individual data sets into one

data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)
                     for iso in country_list)
# Out:
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\1729988833.py:3: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\1729988833.py:3: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\1729988833.py:3: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\1729988833.py:3: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\1729988833.py:3: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\1729988833.py:3: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\1729988833.py:3: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\1729988833.py:3: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\1729988833.py:3: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\1729988833.py:3: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\1729988833.py:3: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\1729988833.py:3: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\1729988833.py:3: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\1729988833.py:3: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\1729988833.py:3: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\1729988833.py:3: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\1729988833.py:3: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_global = pd.concat(pd.read_csv(os.path.join(path, f'{iso}.csv')).assign(iso=iso)

# %%
data_global.head()
# Out:
#          date      admin1          admin2            market   latitude  \
# 0       #date  #adm1+name      #adm2+name  #loc+market+name   #geo+lat
# 1  2000-01-15  Badakhshan       Faiz Abad          Fayzabad  37.116638
# 2  2000-01-15       Balkh  Mazar-e-Sharif             Mazar  36.725116
# 3  2000-01-15       Hirat           Hirat             Hirat  34.346944
# 4  2000-01-15       Hirat           Hirat             Hirat  34.346944
#
#    longitude            category  \
# 0   #geo+lon          #item+type
# 1  70.580022            non-food
# 2  67.109571            non-food
# 3  62.198333  cereals and tubers
# 4  62.198333  cereals and tubers
#
#                                        commodity        unit  \
# 0                                     #item+name  #item+unit
# 1  Wage (non-qualified labour, non-agricultural)         Day
# 2  Wage (non-qualified labour, non-agricultural)         Day
# 3                                          Bread          KG
# 4                                          Wheat          KG
#
#           priceflag         pricetype   currency     price    usdprice  iso
# 0  #item+price+flag  #item+price+type  #currency    #value  #value+usd  AFG
# 1            actual            Retail        AFN  150000.0   3205.7378  AFG
# 2            actual            Retail        AFN  100000.0   2137.1586  AFG
# 3            actual            Retail        AFN     15.63       0.334  AFG
# 4            actual            Retail        AFN      9.13      0.1951  AFG

# %%
data_global.shape
# Out:
# (3542949, 15)

# %% [markdown]
# Saving the warning for future reference: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
# I can see that there are records in the dataframe that contain the names of the columns. I need to remove them

data_global.loc[data_global['price']=='#value']
# Out:
#      date      admin1      admin2            market  latitude longitude  \
# 0   #date  #adm1+name  #adm2+name  #loc+market+name  #geo+lat  #geo+lon
# 0   #date  #adm1+name  #adm2+name  #loc+market+name  #geo+lat  #geo+lon
# 0   #date  #adm1+name  #adm2+name  #loc+market+name  #geo+lat  #geo+lon
# 0   #date  #adm1+name  #adm2+name  #loc+market+name  #geo+lat  #geo+lon
# 0   #date  #adm1+name  #adm2+name  #loc+market+name  #geo+lat  #geo+lon
# ..    ...         ...         ...               ...       ...       ...
# 0   #date  #adm1+name  #adm2+name  #loc+market+name  #geo+lat  #geo+lon
# 0   #date  #adm1+name  #adm2+name  #loc+market+name  #geo+lat  #geo+lon
# 0   #date  #adm1+name  #adm2+name  #loc+market+name  #geo+lat  #geo+lon
# 0   #date  #adm1+name  #adm2+name  #loc+market+name  #geo+lat  #geo+lon
# 0   #date  #adm1+name  #adm2+name  #loc+market+name  #geo+lat  #geo+lon
#
#       category   commodity        unit         priceflag         pricetype  \
# 0   #item+type  #item+name  #item+unit  #item+price+flag  #item+price+type
# 0   #item+type  #item+name  #item+unit  #item+price+flag  #item+price+type
# 0   #item+type  #item+name  #item+unit  #item+price+flag  #item+price+type
# 0   #item+type  #item+name  #item+unit  #item+price+flag  #item+price+type
# 0   #item+type  #item+name  #item+unit  #item+price+flag  #item+price+type
# ..         ...         ...         ...               ...               ...
# 0   #item+type  #item+name  #item+unit  #item+price+flag  #item+price+type
# 0   #item+type  #item+name  #item+unit  #item+price+flag  #item+price+type
# 0   #item+type  #item+name  #item+unit  #item+price+flag  #item+price+type
# 0   #item+type  #item+name  #item+unit  #item+price+flag  #item+price+type
# 0   #item+type  #item+name  #item+unit  #item+price+flag  #item+price+type
#
#      currency   price    usdprice  iso
# 0   #currency  #value  #value+usd  AFG
# 0   #currency  #value  #value+usd  AGO
# 0   #currency  #value  #value+usd  ARG
# 0   #currency  #value  #value+usd  ARM
# 0   #currency  #value  #value+usd  AZE
# ..        ...     ...         ...  ...
# 0   #currency  #value  #value+usd  VNM
# 0   #currency  #value  #value+usd  YEM
# 0   #currency  #value  #value+usd  ZAF
# 0   #currency  #value  #value+usd  ZMB
# 0   #currency  #value  #value+usd  ZWE
#
# [99 rows x 15 columns]

# %%
# Since I haven't reset the index yet, all unnecesary rows are indexed 0

df_global=data_global.drop(data_global.index[0])

# %%
df_global.head()
# Out:
#          date      admin1          admin2    market   latitude  longitude  \
# 1  2000-01-15  Badakhshan       Faiz Abad  Fayzabad  37.116638  70.580022
# 2  2000-01-15       Balkh  Mazar-e-Sharif     Mazar  36.725116  67.109571
# 3  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
# 4  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
# 5  2000-01-15       Hirat           Hirat     Hirat  34.346944  62.198333
#
#              category                                      commodity unit  \
# 1            non-food  Wage (non-qualified labour, non-agricultural)  Day
# 2            non-food  Wage (non-qualified labour, non-agricultural)  Day
# 3  cereals and tubers                                          Bread   KG
# 4  cereals and tubers                                          Wheat   KG
# 5  cereals and tubers                                    Wheat flour   KG
#
#   priceflag pricetype currency     price   usdprice  iso
# 1    actual    Retail      AFN  150000.0  3205.7378  AFG
# 2    actual    Retail      AFN  100000.0  2137.1586  AFG
# 3    actual    Retail      AFN     15.63      0.334  AFG
# 4    actual    Retail      AFN      9.13     0.1951  AFG
# 5    actual    Retail      AFN     10.06      0.215  AFG

# %%
# Now I can reset the index of the dataframe

df_global.reset_index(inplace=True)

# %%
df_global.index
# Out:
# RangeIndex(start=0, stop=3542751, step=1)

# %%
# Changing data types
df_global=df_global.astype({'price':'float','usdprice':'float','latitude':'float','longitude':'float'})
print(df_global.dtypes)
# Out:
# index          int64
# date          object
# admin1        object
# admin2        object
# market        object
# latitude     float64
# longitude    float64
# category      object
# commodity     object
# unit          object
# priceflag     object
# pricetype     object
# currency      object
# price        float64
# usdprice     float64
# iso           object
# dtype: object

# %%
df_global.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#                index       latitude      longitude           price  \
# count  3542751.00000  3515876.00000  3515876.00000   3542751.00000
# mean     49728.05970       13.59380       37.25309      6791.21714
# std      50759.71417       16.61378       46.51168     83441.09058
# min          1.00000      -34.61000     -107.38600         0.00000
# 25%      13118.00000        1.72680        8.68138         1.54000
# 50%      33592.00000       12.32634       34.25617       130.50000
# 75%      67029.00000       27.65266       71.55583      1200.00000
# max     250774.00000       59.93000      179.37736  17250000.00000
#
#             usdprice
# count  3538809.00000
# mean        13.54921
# std       1075.81118
# min          0.00000
# 25%          0.16780
# 50%          0.74070
# 75%          1.99500
# max     599999.99110

# %%
#The total count of rows in the final dataframe has first surprised me. I'm counting the number of rows per country

df_count_by_country=df_global['iso'].value_counts()
df_count_by_country
# Out:
# IDN    250774
# SYR    240503
# IND    177336
# GMB    149692
# PHL    136253
#         ...
# CRI       330
# AZE       149
# VEN       109
# ERI       100
# GEO        80
# Name: iso, Length: 99, dtype: int64

# %%
df_count_by_country.describe()
# Out:
# count        99.000000
# mean      35785.363636
# std       47975.981543
# min          80.000000
# 25%        2655.000000
# 50%       17092.000000
# 75%       51962.000000
# max      250774.000000
# Name: iso, dtype: float64

# %% [markdown]
# #### It looks like Indonesia is the country with the highest number of rows in the dataframe - 250774, while Georgia has only 80 records. To confirm that concatenation has worked correctly, I'll import the individual data sets and check their length.

# %%
df_idn=pd.read_csv(os.path.join(path,'idn.csv'))
# Out:
# C:\Users\frauz\AppData\Local\Temp\ipykernel_13240\3309933425.py:1: DtypeWarning: Columns (4,5,12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_idn=pd.read_csv(os.path.join(path,'idn.csv'))

# %%
df_idn.shape
# Out:
# (250775, 14)

# %%
df_geo=pd.read_csv(os.path.join(path,'geo.csv'))

# %%
df_geo.shape
# Out:
# (81, 14)

# %% [markdown]
# #### It looks like both data sets have been concatenated accurately. At this point, I assume the same for the remaining 97 data sets.

# %%
# The completed dataframe can now be exported and used in the next project phase
df_global.to_pickle(os.path.join(path,'global_food_prices.pkl'))
